# %%
target_url = 'https://www.jobplanet.co.kr'
start_page = 1
end_page = 315
params = {
    'category_id': 16,
    'woe_id': '0',
    'sort' : 'popularity',
    'seed' : 2609642,
    'page' : start_page
}

# %%
from konlpy.tag import Okt

t = Okt()
# Out:
# C:\Users\elris\Anaconda3\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
import requests
from bs4 import BeautifulSoup

# %%
target_url = 'https://www.jobplanet.co.kr/companies/87444/reviews/%EC%BF%A0%ED%8C%A1'
start_page = 1
end_page = 315
params = {
    'page' : start_page
}

# %%
resp = requests.get(target_url, params=params)
resp
# Out:
# <Response [200]>

# %%
resp.encoding
# Out:
# 'utf-8'

# %%
resp.headers
# Out:
# {'Date': 'Thu, 26 Dec 2019 03:29:26 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d7185897aa28663e515a2cfe8fd7f11a41577330965; expires=Sat, 25-Jan-20 03:29:25 GMT; path=/; domain=.jobplanet.co.kr; HttpOnly; SameSite=Lax, request_method=GET; path=/, _jp_visitor_token=5c198b21-d0aa-408f-9f9f-91a6f5f23d8e; path=/; expires=Wed, 26 Dec 2029 03:29:25 -0000, _jp_visit_token=ee891ab6-38ef-49cc-8d21-1cc8d4118f93; path=/; expires=Thu, 26 Dec 2019 07:29:25 -0000, _jp_traffic_source=%7B%22utm_campaign%22%3Anull%2C%22utm_medium%22%3Anull%2C%22utm_source%22%3Anull%7D; path=/; expires=Thu, 26 Dec 2019 07:29:25 -0000, _jp_visit_short_token=1577330965441-598eb53b-c7fb-46c2-903b-44307e359a71; path=/; expires=Thu, 26 Dec 2019 03:39:25 -0000, _jp_induction_status=true; path=/; expires=Fri, 27 Dec 2019 03:29:25 -0000, premiumInfoModalOn_190611=on; path=/; expires=Mon, 26 Dec 2039 03:29:25 -0000, _intween_x2o_net_sessi
# ...

# %%
resp.url
# Out:
# 'https://www.jobplanet.co.kr/companies/87444/reviews/%EC%BF%A0%ED%8C%A1?page=1'

# %%
soup = BeautifulSoup(resp.content)

# %%
soup.head
# Out:
# <head>
# <title>쿠팡 1678건 평균 리뷰 평점 3.03점 기업리뷰 | 잡플래닛</title>
# <meta content="width=1182" name="viewport"/>
# <meta content="쿠팡 1678건 평균 리뷰 평점 3.03점 기업리뷰 | 잡플래닛" name="title"/>
# <meta content="쿠팡 1678건 평균 리뷰 평점 3.03점 기업리뷰" name="keywords"/>
# <meta content="쿠팡의 전/현직원이 전하는 생생한 기업리뷰! 등록된 리뷰 1678건, 평균 리뷰 평점 3.03점, 전체 직원의 44%가 이 기업을 추천합니다!" name="description"/>
# <meta content="쿠팡의 전/현직원이 전하는 생생한 기업리뷰! 등록된 리뷰 1678건, 평균 리뷰 평점 3.03점, 전체 직원의 44%가 이 기업을 추천합니다!" property="description"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script src="/cdn-cgi/apps/head/Pkvo1XfvcUSTQ4tNhbP9Iaf5hmo.js"></script><script>window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"090774e09e","applicationID":"3789469","transactionName":"clcLR0BZDV9cRU5WVlxIBF1bUxIcS1IXXFxGSw==","queueTime":0,"applicationTime":1114,"agent":""}</script>
# ...

# %%
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-a0044bf6c1e8> in <module>
# ----> 1 print(soup.prettify().head)
#
# AttributeError: 'str' object has no attribute 'head'

# %%
import requests
from bs4 import BeautifulSoup

# %%
page_list = soup.find_all('meta', property_ = '')

# %%
page_list
# Out:
# [<meta content="width=1182" name="viewport"/>,
#  <meta content="쿠팡 1678건 평균 리뷰 평점 3.03점 기업리뷰 | 잡플래닛" name="title"/>,
#  <meta content="쿠팡 1678건 평균 리뷰 평점 3.03점 기업리뷰" name="keywords"/>,
#  <meta content="쿠팡의 전/현직원이 전하는 생생한 기업리뷰! 등록된 리뷰 1678건, 평균 리뷰 평점 3.03점, 전체 직원의 44%가 이 기업을 추천합니다!" name="description"/>,
#  <meta content="쿠팡의 전/현직원이 전하는 생생한 기업리뷰! 등록된 리뷰 1678건, 평균 리뷰 평점 3.03점, 전체 직원의 44%가 이 기업을 추천합니다!" property="description"/>,
#  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>,
#  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>,
#  <meta content="C6731F07D45F619A26195CF4D3182432" name="msvalidate.01"/>,
#  <meta content="3710bb9e5207d0fb4b19e0ee5db5a23089eed600" name="naver-site-verification"/>,
#  <meta content="authenticity_token" name="csrf-param"/>,
#  <meta content="2CcYFipIgaPNy9tfSbpkT+FUenB/BVkRXc9u7AHHliM=" name="csrf-token"/>,
# ...

# %%
page_list[11]
# Out:
# <meta content="세련되고 협력이 이루어지며 다양한 차원에서 소통이 잘 이루어짐. (장점) 합리적이고 변화에 적극적인 모습. 시스템이 잘 구축되어있는 편이며 특정 개인의 성향에 따라 좌지우지되는 운영의 모습이 크게 나타나지는 않음 (단점) 승진에 대한 고민이 많이 드는데, 쉽게 승진하기는 어려울 것 같다는 생각을 함. 근데 이건 기업의 단점이라기보다는 경영사무직에서는 공통으로 나타나는 문제인 것 같음" property="og:description"/>

# %%
print(page_list[11].prettify())
# Out:
# <meta content="세련되고 협력이 이루어지며 다양한 차원에서 소통이 잘 이루어짐. (장점) 합리적이고 변화에 적극적인 모습. 시스템이 잘 구축되어있는 편이며 특정 개인의 성향에 따라 좌지우지되는 운영의 모습이 크게 나타나지는 않음 (단점) 승진에 대한 고민이 많이 드는데, 쉽게 승진하기는 어려울 것 같다는 생각을 함. 근데 이건 기업의 단점이라기보다는 경영사무직에서는 공통으로 나타나는 문제인 것 같음" property="og:description"/>

# %%
type(page_list[11])
# Out:
# bs4.element.Tag

# %%
page_list[11]['content']
# Out:
# '세련되고 협력이 이루어지며 다양한 차원에서 소통이 잘 이루어짐. (장점) 합리적이고 변화에 적극적인 모습. 시스템이 잘 구축되어있는 편이며 특정 개인의 성향에 따라 좌지우지되는 운영의 모습이 크게 나타나지는 않음 (단점) 승진에 대한 고민이 많이 드는데, 쉽게 승진하기는 어려울 것 같다는 생각을 함. 근데 이건 기업의 단점이라기보다는 경영사무직에서는 공통으로 나타나는 문제인 것 같음'

# %%
datafile = []
start_page = 1
end_page = 300
good = []
bad = []
datastr = ''

for i in range(start_page, end_page) : 
    target_url = 'https://www.jobplanet.co.kr/companies/87444/reviews/%EC%BF%A0%ED%8C%A1'
    params = {'page' : i}
    resp = requests.get(target_url, params=params)
    soup = BeautifulSoup(resp.content)
    page_list = soup.find_all('meta', property_ = '')
    page_list
    review = page_list[11]['content'].split("(장점)")
    review = review[1].split("(단점)")
    good.append(review[0])
    bad.append(review[1])
print(good[0:10])
print(bad[0:10])
# Out:
# [' 합리적이고 변화에 적극적인 모습. 시스템이 잘 구축되어있는 편이며 특정 개인의 성향에 따라 좌지우지되는 운영의 모습이 크게 나타나지는 않음 ', ' 어마어마한 적자를 내어 가면 치킨게임을 주도하고 있음. 단 매출 성장만은 어마어마함 ', ' 근무 시간이 자유로운 부분이 최대 장점으로 뽑을 수 있다 ', ' 사원을 존중해줘요 수평적인 조직관계가 인상적이에요. 수직적인 관계가 아니라서 편했어요 일만 열심히 하면됨 ', ' 월급이 밀릴일이없음, 택배하나를 받기위해 얼마나 많은 손이 거치는지를 알 수 있는곳 ', ' 연차 눈치 안보고 자유롭게 쓸수있다. 상사라는 개념보다는 평등한 분위기에서 일한다. 선착순으로 조식이 무료이다. ', ' 연차 자유롭게 쓰고 아주 수평적인 문화, 상호 존중 및 존대하면서 직급안 부르고 닉네임으로 부르는 형태. ', ' 유통의 최고를 꿈꾸는 기업으로 도전정신과 능동적으로 일할수 있는 환경이라 좋았습니다.\n ', ' 연차 자유롭게 사용 가능, 사내 교육시스템 잘되어있음,  수평조직 관계를 추구하는 편 ', ' 칼퇴가능하다. 아침 일찍가면 간식을 준다. 직원 연령대가 젊다. ', ' 특정한 파트에서 고인물이 되게 하는 것이 아닌 이곳저곳으로 조금씩 옮기며 다양한 경험을 할 수 있어서 개인적 성장과 부서 내에 전체적인 그림을 그리기에는 좋을 것 같음. 닉네임을 사용하는 등 한국 특유의 수직적인 문화보다는 조금이라도 수평적인 문화를 통해 소통의 기회를 넓히려는 것이 느껴짐. 사람에 따라 다르지만 함께 으샤으샤하려는 분들이 있어서 좋은 사람들과 일 할 수 있어서 큰 힘이 되었음. 계약서대로 칼같이 지킴. ', ' 조직 내 개발문화에 대해 많은 것을 배움. 외국인과 커뮤니케이션 할 일이 많아서 영어를 쓸 일이 많음 ', ' 항상 존댓말 써주시고, 일자체가 다른 물류 창고(옥처너블 등등)에비하면 수월해요. 저는 영상 2도 정도의 냉장창고에서 일했는데 땀도 안나고 좋았어요 ', ' 출퇴근이 30분정도 늦어서 다소 출퇴근시간에 압박이 덜하다는 
# ...

# %%
import konlpy
from konlpy.tag import Kkma
kkma = Kkma()

# %%
coupang_bad = ''
for i in bad : 
    coupang_bad += i
coupang_bad
# Out:
# " 승진에 대한 고민이 많이 드는데, 쉽게 승진하기는 어려울 것 같다는 생각을 함. 근데 이건 기업의 단점이라기보다는 경영사무직에서는 공통으로 나타나는 문제인 것 같음 홈플러스 패잔병들이 골목대장을 하고 있는 대한민국 최고의 꼰대 기업 실력없는 사람이 생각보다 많음\r\n정치질 심함\r\n직원끼리 거짓말은 기본 휴식시간이 별로 없어요 몇 시간 동안 휴식없이 일해야 할때도 있어요. 1인이 해결해야 할 업무량이 꽤 많아요. 열심히 하면 할 수는 있음 일을 시작한 초반에는 주로 몸쓰는 일을 많이함, 그러다가 어느정도 경력이 쌓이면 몸을 안쓰는일을 할수있는 차별을 당함.\n다치면 무조건 본인 잘못으로 몰아감. 월급을 받으면 몸을위해 돈을쓰고 남는돈은 많이없음. 20대 직원들이 많은 것은 장점이자 단점이라고 생각한다. 별거아닌것도 소문이 금방 확대되어 퍼진다. 대학생활의 연장선 같은 느낌이다. 사회생활을 배울만한 어른의 수가 부족하다. 그날 주어진 일을 못끝내면 퇴근을 못하고 야근해서라도 다끝내거나 필요하다면 주말근무까지 한다 특별한건 없지만 아직 체계등 조직이 잡혀 있지 않았습니다.\n하지만 크게 단점이라 말할수 없습니다. 발전된다는 느낌이 없음, 회사 내에 식당이 없어서 매일 도시락을 싸 다니거나 뭐먹을지 고민함 매우 불만족스러음 위의 장점 외에는 전부 단점이라고 보면 된다. 사람이 아닌 기계를 바라는 회사 야근과 그에 대한 보상이 어떤지 사실 잘 모르겠음. 그렇게 좋은 환경이라고 생각하지는 않음. 경영진의 마인드는 오픈마인드이나, 그 아래로는 글쎄... 부서마다 다르겠지만 승진기회 및 가능성이 매우 낮아보이며, 샌드위치로 휴가 쓸 때 눈치싸움을 살짝 해야할 수 있음. 회사가 한국인 개발자보다 외국인 개발자 위주로 돌아간다는 인상을 지우기 힘들다. 허리가 아픈건 어쩔 수 없더군요. 그리구 하는 일에 비해 시급이 짠 부분은 있는 거 같아요. 요즘 알바 시급 만원하는 곳도 솔찍히 많으니까요 ㅠㅠ 그리고 한번일하고오면 스팸문자 너무 많이와요 상대적으로 본인 업무를 기
# ...

# %%
datastr
# Out:
# ''

# %%
import konlpy
from konlpy.tag import Kkma
kkma = Kkma()

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image

# %%
import nltk  
from nltk.corpus import stopwords

# %%
import platform
import matplotlib.pyplot as plt

# %matplotlib inline


path = "c:/Windows/Fonts/10X10.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
import wordcloud

# %%
import re

# %%
import sys
flags = (re.UNICODE if sys.version < '3' and type(text) is unicode  # noqa: F821
                 else 0)

# %%
t.nouns(coupang_bad)[0:10]
# Out:
# ['승진', '대한', '고민', '승진', '것', '생각', '함', '이건', '기업', '단점']

# %%
type(t.nouns(coupang_bad))
# Out:
# list

# %%
coupang1 = t.nouns(coupang_bad)

# %%
set(coupang1[0:10])
# Out:
# {'것', '고민', '기업', '단점', '대한', '생각', '승진', '이건', '함'}

# %%
coupang_wk = []
for i in coupang1 : 
    if len(i) == 1 :
        True
    else : 
        coupang_wk.append(i)
coupang_wk[0:10]
# Out:
# ['승진', '대한', '고민', '승진', '생각', '이건', '기업', '단점', '사무직', '공통']

# %%
coupang_wk1 = ''
for i in range(len(coupang_wk)) : 
    if coupang_wk[i] == '분위기' :
        True
    elif coupang_wk[i] == '사람' :
        True
    elif coupang_wk[i] == '생각' :
        True
    else : 
        coupang_wk1 += coupang_wk[i]
        coupang_wk1 += ','
coupang_wk1
# Out:
# '승진,대한,고민,승진,이건,기업,단점,사무직,공통,문제,홈플러스,패잔,골목,대장,대한민국,최고,꼰대,기업,실력,정치,직원,끼리,거짓말,기본,휴식시간,별로,시간,동안,휴식,일해,해결,무량,시작,초반,주로,정도,경력,차별,무조건,본인,잘못,월급,위해,직원,장점,이자,단점,별거,소문,금방,확대,대학,생활,장선,느낌,사회생활,어른,수가,그날,퇴근,야근,주말,근무,체계,조직,크게,단점,발전,느낌,회사,식당,매일,도시락,고민,매우,불만족,장점,전부,단점,기계,회사,야근,대한,보상,사실,환경,경영,진의,마인드,오픈,마인드,아래,글쎄,부서,승진,기회,가능성,매우,보이,샌드위치,휴가,눈치,싸움,살짝,회사,한국인,개발자,외국인,개발자,위주,인상,허리,시급,부분,요즘,알바,시급,만원,곳도,한번,스팸문자,상대,본인,업무,기준,때문,개인플레이,부분,제한,본인,해당,업무,자체,헬임,무엇,규정,시도,매번,숙지,전부,복지,혜택,거의,평가,제도,기준,결과,대해,인정,성과,주의,매일,압박,연속,처리,속도,심리,압박,무니,월급,월급,격차,매우,가나,곳도,월급,미래,보장,직종,회사,점점,무량,인력,처우,개선,불확실,장점,이외,전부,멀리,버스,힘들엇어용,꼰대,부장,출퇴근,성장,업무,체게,리스크,존재,외국인,근로자,근로자,대한,불신,팽배,담배,시간,몰래,기분,미래,박봉,경력,연봉,차이,정규직,전환,해도,베이스,최저,시급,이기,때문,연봉,상승,어려움,동시,야근,조직,변화,정착,추천,업무,여러,경우,커리어,마인드,업무,스트레스,존재,경력,쿠팡,이직,회사,업무,임금,무니,체계,느낌,영어,실무,능력,한계,실시간,업무,현황,공유,시스템,부족함,인사,인력,부족함,특정,안건,대해,이견,직원,업무,직원,보호,물류,특성,동료,소통,기회,회식,구조,다소,아쉬움,그냥,전화,체계,텃새,기도,업무,자체,고객,지원,업무,스트레스,인력,턴오버,한편,위로,발전,가능성,업무,체계,업무,방식,기준,자주,문화,개인,팀원,끼리,화합,구내식당,나이,한가지,여러가지,시킴,한가지,일로,적자,연속,연봉,편이,상여금,거의,떡값,수준,영진
# ...

# %%
from wordcloud import get_single_color_func

class SimpleGroupedColorFunc(object):
    def __init__(self, color_to_words, default_color):
        self.word_to_color = {word: color
                              for (color, words) in color_to_words.items()
                              for word in words}

        self.default_color = default_color

    def __call__(self, word, **kwargs):
        return self.word_to_color.get(word, self.default_color)

class GroupedColorFunc(object):
    def __init__(self, color_to_words, default_color):
        self.color_func_to_words = [
            (get_single_color_func(color), set(words))
            for (color, words) in color_to_words.items()]

        self.default_color_func = get_single_color_func(default_color)

    def get_color_func(self, word):
        """Returns a single_color_func associated with the word"""
        try:
            color_func = next(
                color_func for (color_func, words) in self.color_func_to_words
                if word in words)
        except StopIteration:
            color_func = self.default_color_func

        return color_func

    def __call__(self, word, **kwargs):
        return self.get_color_func(word)(word, **kwargs)

# %%
wc = WordCloud(font_path = 'path = "c:/Windows/Fonts/10X10.ttf', background_color = 'white', width = 800, height = 500, max_words = 3000, collocations=False)
wc = wc.generate(coupang_wk1)
wc.words_
# Out:
# {'업무': 1.0,
#  '회사': 0.6043956043956044,
#  '직원': 0.4065934065934066,
#  '체계': 0.37362637362637363,
#  '외국인': 0.34065934065934067,
#  '부서': 0.3076923076923077,
#  '연봉': 0.2857142857142857,
#  '계약': 0.27472527472527475,
#  '복지': 0.24175824175824176,
#  '시간': 0.23076923076923078,
#  '경우': 0.23076923076923078,
#  '느낌': 0.21978021978021978,
#  '조직': 0.21978021978021978,
#  '반복': 0.21978021978021978,
#  '파견': 0.2087912087912088,
#  '정규직': 0.1978021978021978,
#  '문화': 0.1978021978021978,
#  '대한': 0.18681318681318682,
#  '야근': 0.18681318681318682,
#  '영어': 0.18681318681318682,
#  '효율': 0.18681318681318682,
#  '단순': 0.17582417582417584,
#  '승진': 0.16483516483516483,
#  '때문': 0.16483516483516483,
#  '평가': 0.16483516483516483,
#  '변화': 0.15384615384615385,
#  '작업': 0.15384615384615385,
#  '하나': 0.15384615384615385,
#  '기업': 0.14285714285714285,
#  '단점': 0.14285714285714285,
#  '발전': 0.14285714285714285,
#  '매우': 0.14285714285714285,
#  '거의': 0.14285714285714285,
#  '쿠팡': 0.14285714285714285,
# ...

# %%
import numpy as np
import random
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
from palettable.colorbrewer.qualitative import Dark2_8
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return tuple(Dark2_8.colors[random.randint(0,7)])

# %%
wc.recolor(color_func=color_func, random_state=3)
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
